# %% [markdown]
# <a href="https://colab.research.google.com/github/Himanshusharma3411/Python01/blob/main/Python01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.core.prefilter import PythonOpsChecker
from IPython.core.interactiveshell import AliasManager
print("Hello") #Hi, i am starting python
'''
hi i am
starting Python
code today
'''
# Out:
# Hello
